# %% [markdown]
# <a href="https://colab.research.google.com/github/baruasumit509/AdventureWork-Project-Power-BI/blob/main/Discover.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ocr wi

# %%
# !pip install -q keras-ocr

# %%
import keras_ocr
import matplotlib.pyplot as plt

# %%
pipeline=keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %%
images = [keras_ocr.tools.read(img) for img in ['/content/Book.jpg','/content/Dhoni.jpg']]

# %%
len(images)
# Out:
# 2

# %%
plt.figure(figsize=(10,10))
plt.imshow(images[0])

# %%
plt.figure(figsize=(10,10))
plt.imshow(images[1])

# %%
prediction_groups=pipeline.recognize(images)

# %%
#import itertools
fig,axs=plt.subplots(nrows=len(images),figsize=(10,20))
for ax, image, predictions in zip(axs, images, prediction_groups):
  keras_ocr.tools.drawAnnotations(image=image,predictions=predictions,ax=ax)
